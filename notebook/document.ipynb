# %% [markdown]
# ### Data Ingestion

# %%
### Document Structure
from langchain_core.documents import Document

# %%
doc=Document(page_content="This is a test document.", metadata={"source": "test.txt"})
print(doc)
# Out:
# page_content='This is a test documentjj.' metadata={'source': 'test.txt'}

# %%
# create a simple txt file
import os 
os.makedirs("./data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}
print(sample_texts.items())
for file_path, content in sample_texts.items():
    with open(file_path, "w") as f:
        f.write(content)
    print("Sample text files created successfully.")
# Out:
# dict_items([('../data/text_files/python_intro.txt', 'Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'), ('../data/text_files/machine_learning.txt', 'Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    ')])
# Sample text files created successfully.
# Sample text files created successfully.

# %%
### Text Loader
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

### load all the text files form the directory
dir_loader = DirectoryLoader("../data/text_files", glob="**/*.txt",loader_cls=TextLoader, loader_kwargs={"encoding": "utf-8"}, show_progress=False)

documents = dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader , PyMuPDFLoader

### load pdf file 
dir_loader = DirectoryLoader("../data/pdf",glob="**/*.pdf",loader_cls=PyMuPDFLoader, show_progress=False)
pdf_documents = dir_loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': 'Skia/PDF m89', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\oops 1 notes.pdf', 'file_path': '..\\data\\pdf\\oops 1 notes.pdf', 'total_pages': 9, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content="Object-Oriented Programming (OOPS-1)\xa0\n\xa0\nIntroduction to OOPS\xa0\nObject-oriented programming System(OOPs)\u200b is a programming paradigm based\xa0\non the concept of \u200b“objects”\u200b and \u200b“classes”\u200b that contain data and methods. The\xa0\nprimary purpose of OOP is to increase the flexibility and maintainability of\xa0\nprograms. It is used to structure a software program into simple, reusable pieces of\xa0\ncode \u200bblueprints\u200b (called \u200bclasses\u200b) which are used to create individual instances of\xa0\nobjects\u200b.\xa0\n\xa0\nWhat is an Object?\xa0\nThe object is an entity that has a state and a behavior associated with it. It may be\xa0\nany real-world object like the mouse, keyboard, chair, table, pen, etc.\xa0\nObjects have states and behaviors. Arrays are objects.\u200b You've been using objects all\xa0\nalong and may not even realize it. Apart from primitive data types, objects are all\xa0\naround in java.\xa0\nWhat is a Class?\xa0\nA class is a \u200bblueprint\u200b that defines the variables and the methods (Characteristics)\xa0\ncommon to all objects of a certain kind.\xa0\xa0\nExample:\u200b If \u200bCar\u200b is a class, then \u200bMaruti 800\u200b is an object of the \u200bCar\u200b class. All cars share\xa0\nsimilar features like 4 wheels, 1 steering wheel, windows, breaks etc. Maruti 800 (The \u200bCar\xa0\nobject) has all these features.\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n1"), Document(metadata={'producer': 'Skia/PDF m89', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\oops 1 notes.pdf', 'file_path': '..\\data\\pdf\\oops 1 notes.pdf', 'total_pages': 9, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='Classes vs Objects (Or Instances)\xa0\nClasses are used to create user-defined data structures. Classes define functions\xa0\ncalled \u200bmethods\u200b, which identify the behaviors and actions that an object created\xa0\nfrom the class can perform with its data.\xa0\nIn this module, you’ll create a \u200bCar\u200b class that stores some information about the\xa0\ncharacteristics and behaviors that an individual \u200bCar \u200bcan have.\xa0\nA class is a blueprint for how something should be defined. It doesn’t contain any\xa0\ndata. The \u200bCar\u200b class specifies that a name and a top-speed are necessary for\xa0\ndefining a \u200bCar\u200b, but it doesn’t contain the name or top-speed of any specific \u200bCar\u200b.\xa0\nWhile the class is the blueprint, an instance is an object that is built from a class and\xa0\ncontains real data. An instance of the \u200bCar\u200b class is not a blueprint anymore. It’s an\xa0\nactual car with a \u200bname\u200b, like Creta, and with a \u200btop speed\u200b of 200 Km/Hr.\xa0\nPut another way, a class is like a form or questionnaire. An \u200binstance\u200b is like a form\xa0\nthat has been filled out with information. Just like many people can fill out the same\xa0\nform with their unique information, many instances can be created from a single\xa0\nclass.\xa0\n\xa0\n\xa0\nDefining a Class in Java\xa0\nAll class definitions start with the \u200bclass\u200b keyword, which is followed by the name of\xa0\nthe class.\xa0\xa0\nHere is an example of a \u200bCar\u200b class:\xa0\n\xa0\n2\xa0\nclass\u200b \u200bCar{ \n \n \n}'), Document(metadata={'producer': 'Skia/PDF m89', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\oops 1 notes.pdf', 'file_path': '..\\data\\pdf\\oops 1 notes.pdf', 'total_pages': 9, 'format': 'PDF 1.5', 'title': '', 'aut ...
